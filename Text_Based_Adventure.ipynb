# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/text-based-adventure-DocHoliday717/blob/main/Text_Based_Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Requirements for text based adventure
# 1. You must have at least 2 different "paths" that are at least 4 decisions in length
# 2. Include an element of randomness (from the random library)
# 3. Include a list that is core to the text based adventure
# 4. Include a function that is called within your program that includes a while loop, and a parameter that influences a conditional statement in your function.
# 5. Commented Code.
# 6. A [digital flowchart](https://docs.google.com/document/d/1p2k3wL6gzjYWBuWxwEQptmbbOZZNsQrthlC12SNtYgY/edit?usp=sharing) that follows accepted symbols for representing code. You can use google slides or [draw.io](https://www.drawio.com/) for the flowchart.

# %%
def responseValidator(response):
  while response != "Y" and response != "N":
    response = input("Invalid Response: please type 'Y' or 'N': ")
  return response

# %%
def intro():
  response = input("You wake up, dreading another day of working at Gandalf's. Do you go to work? Y or N: ")
  return response

# %%
def choice1(response):
  response = responseValidator(response)

  if response == "Y":
    print("You go to work.")
    return(response)

  elif response == "N":
    print("You stay home.")
    return(response)

# %%
def gandalfWork():
  print("Another day another wizard")
  response = input("You hear a clank... do you investigate? Y or N: ")
  return response

# %%
def choice2(response):
  response = responseValidator(response)

  if response == "Y":
    print("You go check out the noise.")
    return response

  elif response == "N":
    print("You stay put.")

# %%
def aisle():
  print("What could be going on here?")
  print("Upon getting to the aisle, you see two wizards seemingly... robbing the place!")
  response = input("They haven't noticed you yet, you could run away, or you could try to confront them. Do you want to confront them? Y or N: ")
  return response

# %%
def choice3b(response):
  response = responseValidator(response)

  if response == "Y":
    print("You steel your nerves, and confront the thieving wizards.")
    return(response)

  elif response == "N":
    print("You decide it's not worth it, and slink away.")
    return(response)

# %%
def register():
  print("Could anything be more monotonous?")
  response = input("Eriboser, a regular, comes up asking for a runic lottery ticket. You know he's a chronic gambler, and you probably shouldn't give him the ticket. Do you? Y or N: ")
  return response

# %%
def choice3a(response):
  response = responseValidator(response)

  if response == "Y":
    print("You hand over the lottery ticket.")
    return(response)

  elif response == "N":
    print("You refuse and tell him that they are... not in stock, yeah.")
    return(response)

# %%
import random

def main():
  response = intro()
  response = choice1(response)
  if response == "Y":
    gandalfWork()
  elif response == "N":
    endingA = random.randint(1, 2)
    if endingA == 1:
      print("Tyreculis was able to pick up your shift since he still owes you for the sheckels you lent him")
      print("Ending 1: W Tyreculis")
    else:
      print("You got fired because you didn't show up. How will you make sheckels now?")
      print("Ending 2: No Sheckels?")

    print("Game Over")
  response = choice2(response)
  if response == "N":
    register()

# %%
main()
# Out:
# You wake up, dreading another day of working at Gandalf's. Do you go to work? Y or N: N
# You stay home.
# You got fired because you didn't show up. How will you make sheckels now?
# Ending 2: No Sheckels?
# Game Over
# You stay put.
